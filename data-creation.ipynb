# %%
import requests
import dotenv 
import os
from tqdm import tqdm
dotenv.load_dotenv()
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")

# %%
ENDPOINT = 'https://api.github.com/graphql'
HEADERS_QGL = {
    "Authorization": f"Bearer {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.starfire-preview+json",
}

# %%
def search_repos_query(query, after_cursor=None):
    if after_cursor is None:
        query = """
        {
            search(query: """ + query  + """ , type: REPOSITORY, first: 100) {
                pageInfo {
                    hasNextPage
                    endCursor
                }
                nodes {
                    ... on Repository {
                        nameWithOwner
                        stargazerCount
                        primaryLanguage {
                            name
                        }
                        issueTemplates {
                            filename
                            body
                            name
                            title
                        }
                        owner {
                            login
                        }
                        pullRequestTemplates {
                            filename
                            body
                        }
                        primaryLanguage {
                            name
                        }
                        hasWikiEnabled
                        description
                    }
                }
            }
        }
        """
    else:
        query = '''
        {
            search(query: "stars:>1000", type: REPOSITORY, first: 100, after: ''' + after_cursor + ''') {
                pageInfo {
                    hasNextPage
                    endCursor
                }
                nodes {
                    ... on Repository {
                        nameWithOwner
                        stargazerCount
                        primaryLanguage {
                            name
                        }
                        issueTemplates {
                            filename
                            body
                            name
                            title
                        }
                        owner {
                            login
                        }
                        pullRequestTemplates {
                            filename
                            body
                        }
                        primaryLanguage {
                            name
                        }
                        hasWikiEnabled
                        description
                    }
                }
            }
        }
        '''
    return query

def form_query(query, after_cursor=None):
    if after_cursor is None:
        return search_repos_query(query)
    else:
        return search_repos_query(query,after_cursor=after_cursor)

# %%
def get_repos_from_query(query):
    templates_repo = []
    individual_issue_contents = []
    individual_pr_contents = []
    after_cursor = None
    total_projects = 0
    for i in range(1, 11):
        print(f"Page {i}")
        query = form_query(query, after_cursor=after_cursor)
        response = requests.post(ENDPOINT, json={'query': query}, headers=HEADERS_QGL)
        data = response.json()
        after_cursor = '"' + data["data"]["search"]["pageInfo"]["endCursor"] + '"'
        total_projects += len(data["data"]["search"]["nodes"])
        for node in data["data"]["search"]["nodes"]:
            # check if the repo has issue templates and pull request templates
            if node["issueTemplates"] and node["pullRequestTemplates"]:
                # add the repo to the list
                # form a json object
                json_data = {}
                issue_files = []
                for templates in node["issueTemplates"]:
                    issue_contents_data = {}
                    issue_contents_data['repo'] = node["nameWithOwner"]
                    issue_contents_data['owner'] = node["owner"]["login"]
                    issue_contents_data['issue_file'] = templates['filename']
                    issue_contents_data['title'] = templates['title']
                    issue_contents_data['body'] = templates['body']
                    issue_contents_data['name'] = templates['name']
                    issue_files.append(templates['filename'])
                    individual_issue_contents.append(issue_contents_data)
                file_names = []
                for templates in node["pullRequestTemplates"]:
                    pr_contents_data = {}
                    pr_contents_data['repo'] = node["nameWithOwner"]
                    pr_contents_data['owner'] = node["owner"]["login"]
                    pr_contents_data['pr_file'] = templates['filename']
                    pr_contents_data['body'] = templates['body']
                    file_names.append(templates['filename'])
                    individual_pr_contents.append(pr_contents_data)
                if node['primaryLanguage'] is None:
                    if "language:" in query:
                        query_lang = query.split("language:")[1].split(" ")[0]
                        json_data['primaryLanguage'] = query_lang
                    else:
                        json_data['primaryLanguage'] = "None"
                else:
                    json_data['primaryLanguage'] = node['primaryLanguage']['name']
                if node['description'] is None:
                    json_data['description'] = "None"
                else:
                    json_data['description'] = node['description']
                json_data['hasWikiEnabled'] = node['hasWikiEnabled']
                json_data['stargazerCount'] = node['stargazerCount']
                json_data['pull_request_files'] = file_names
                json_data['issue_files'] = issue_files
                json_data['nameWithOwner'] = node['nameWithOwner']
                json_data['owner'] = node['owner']['login']
                templates_repo.append(json_data)
        if not data["data"]["search"]["pageInfo"]["hasNextPage"]:
            break

    print(len(templates_repo))
    print(total_projects)
    return templates_repo, individual_issue_contents, individual_pr_contents, total_projects

# %%
all_templates_repo = []
all_issue_contents = []
all_pr_contents = []
all_total_projects = 0
# get stars:>1000 repos 
query = '"stars:>1000"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects
# get top python repos
query = '"stars:>1000 language:python"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects


# get top java repos
query = '"stars:>1000 language:java"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects


# get top javascript repos
query = '"stars:>1000 language:javascript"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects


# get top c++ repos
query = '"stars:>1000 language:c++"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:c"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:go"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:ruby"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:php"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:rust"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:swift"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

query = '"stars:>1000 language:typescript"'
templates_repo, individual_issue_contents, individual_pr_contents, total_projects = get_repos_from_query(query=query)
all_templates_repo.extend(templates_repo)
all_issue_contents.extend(individual_issue_contents)
all_pr_contents.extend(individual_pr_contents)
all_total_projects += total_projects

print(all_total_projects)
print(len(all_templates_repo))
# Out:
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 182
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 186
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 181
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 188
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 185
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 173
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 197
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 182
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 178
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 194
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 176
# 1000
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# 187
# 1000
# 12000
# 2209

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

df = pd.DataFrame(all_templates_repo)

for repo in all_templates_repo:
    repo['nameWithOwner'] = repo['nameWithOwner'].replace('/', '_')
    repo['owner'] = repo['owner'].replace('/', '_')
    repo['description'] = repo['description']
    repo['issue_files_to_str'] = ",".join(repo['issue_files']) 
    repo['pull_request_files_to_str'] = ",".join(repo['pull_request_files'])
    df = df.append(repo, ignore_index=True)

df.to_csv('templates_repo.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hj/hqb_52jn35x_09z5ptx014d40000gn/T/ipykernel_3444/2801315487.py in <cell line: 6>()
#       4 warnings.filterwarnings('ignore')
#       5
# ----> 6 df = pd.DataFrame(all_templates_repo)
#       7
#       8 for repo in all_templates_repo:
#
# NameError: name 'all_templates_repo' is not defined

# %%
issue_df = pd.DataFrame(all_issue_contents)

for issue_content in individual_issue_contents:
    issue_content['repo'] = issue_content['repo'].replace('/', '_')
    issue_content['owner'] = issue_content['owner'].replace('/', '_')
    issue_content['issue_file'] = issue_content['issue_file'].replace('/', '_')
    issue_content['body'] = issue_content['body'].replace('/', '_')
    issue_content['name'] = issue_content['name'].replace('/', '_')
    issue_content['issue_file'] = issue_content['issue_file'].replace('/', '_')
    issue_df = issue_df.append(issue_content, ignore_index=True)

issue_df.to_csv('individual_issue_contents.csv', index=False)

# %%
issue_df
# Out:
#                          repo      owner                      issue_file  \
# 0              facebook/react   facebook                   bug_report.md
# 1     getify/You-Dont-Know-JS     getify             content-question.md
# 2     getify/You-Dont-Know-JS     getify  foreign-translation-request.md
# 3     getify/You-Dont-Know-JS     getify     report-technical-mistake.md
# 4     getify/You-Dont-Know-JS     getify         textual-grammar-typo.md
# ...                       ...        ...                             ...
# 6569              forem_forem      forem                   bug_report.md
# 6570         go-kratos_kratos  go-kratos                   bug-report.md
# 6571         go-kratos_kratos  go-kratos              feature-request.md
# 6572         go-kratos_kratos  go-kratos                     proposal.md
# 6573         go-kratos_kratos  go-kratos                     question.md
#
#            title                                               body  \
# 0          Bug:   <!--\n  Please provide a clear and concise des...
# 1           None  **Yes, I promise I've read the [Contributions ...
# 2           None  Foreign translations are appreciated. However,...
# 3           None  **Yes, I promise I've read the [Contributions ...
# 4           None  **Yes, I promise I've read the [Contributions ...
# ...          ...                                                ...
# 6569              <!-- Before creating a bug report, try disabli...
# 6570              <!--\nPlease answer these questions before sub...
# 6571   [Feature]  Please see the FAQ in our main README.md befor...
# 6572  [Proposal]  Please see the FAQ in our main README.md befor...
# 6573  [Question]  Please see the FAQ in our main README.md befor...
#
#                              name
# 0                    🐛 Bug Report
# 1                Content Question
# 2     Foreign Translation Request
# 3        Report Technical Mistake
# 4            Textual/Grammar Typo
# ...                           ...
# 6569                   Bug report
# 6570                 🐛 Bug Report
# 6571            💡 Feature Request
# 6572           🧱 Proposal Request
# 6573                   🚀 Question
#
# [6574 rows x 6 columns]

# %%
pr_df = pd.DataFrame(all_pr_contents)

for pr_content in individual_pr_contents:
    pr_content['repo'] = pr_content['repo'].replace('/', '_')
    pr_content['owner'] = pr_content['owner'].replace('/', '_')
    pr_content['pr_file'] = pr_content['pr_file'].replace('/', '_')
    pr_content['body'] = pr_content['body'].replace('/', '_')
    pr_df = pr_df.append(pr_content, ignore_index=True)

pr_df.to_csv('individual_pr_contents.csv', index=False)

# %%
# load cvs file 
df = pd.read_csv('templates_repo.csv')

# remove issue_files and pull_request_files columns that have nan values and just ',' in them
df = df.dropna(subset=['issue_files', 'pull_request_files'], how='all')
df = df[(df['issue_files'] != ',') & (df['pull_request_files'] != ',')]
df = df.reset_index(drop=True)

df = df.drop_duplicates(subset=['nameWithOwner', 'owner'], keep='first')
df = df.reset_index(drop=True)

df['issue_files_to_str'] = df['issue_files'].apply(lambda x: x.replace('[', ''))
df['issue_files_to_str'] = df['issue_files_to_str'].apply(lambda x: x.replace(']', ''))
df['issue_files_to_str'] = df['issue_files_to_str'].apply(lambda x: x.replace("'", ''))
df['issue_files_to_str'] = df['issue_files_to_str'].apply(lambda x: x.replace(" ", ''))

df['pull_request_files_to_str'] = df['pull_request_files'].apply(lambda x: x.replace('[', ''))
df['pull_request_files_to_str'] = df['pull_request_files_to_str'].apply(lambda x: x.replace(']', ''))
df['pull_request_files_to_str'] = df['pull_request_files_to_str'].apply(lambda x: x.replace("'", ''))
df['pull_request_files_to_str'] = df['pull_request_files_to_str'].apply(lambda x: x.replace(" ", ''))

df['len_of_issue_files'] = df['issue_files_to_str'].apply(lambda x: len(x.split(',')))
df['len_of_pull_request_files'] = df['pull_request_files_to_str'].apply(lambda x: len(x.split(',')))
# Out:
#     primaryLanguage                                        description  \
# 1              None    A book series on JavaScript. @YDKJS on twitter.
# 3              Dart  Flutter makes it easy and fast to build beauti...
# 4        TypeScript                                 Visual Studio Code
# 6            Python  Command-line program to download videos from Y...
# 7          Markdown  刷算法全靠套路，认准 labuladong 就够了！English version supp...
# ..              ...                                                ...
# 530           Swift                                    Firefox for iOS
# 533           Swift                Websockets in swift for iOS and OSX
# 534           Swift  A tool for defining design systems and using t...
# 536           Swift                          Windows alt-tab on macOS
# 537           Swift  SwiftEntryKit is a presentation library for iO...
#
#      hasWikiEnabled  stargazerCount            pull_request_files  \
# 1             False          167317  ['PULL_REQUEST_TEMPLATE.md']
# 3              True          152884  ['PULL_REQUEST_TEMPLATE.md']
# 4              True          145835  ['pull_request_template.md']
# 6             False          120085  ['PULL_REQUEST_TEMPLATE.md']
# 7              True          115851  ['PULL_REQUEST_TEMPLATE.md']
# ..              ...             ...                           ...
# 530            True           11349     ['PULL_REQUEST_TEMPLATE']
# 533            True            7713  ['pull_request_template.md']
# 534            True            7514  ['PULL_REQUEST_TEMPLATE.md']
# 536            True            7286  ['pull_request_template.md']
# 537            True            6202  ['PULL_REQUEST_TEMPLATE.md']
#
#                                            issue_files  \
# 1    ['content-question.md', 'foreign-translation-r...
# 3    ['4_performance_others.md', '5_performance_spe...
# 4              ['bug_report.md', 'feature_request.md']
# 6    ['1_broken_site.md', '2_site_support_request.m...
# 7                        ['others.md', 'translate.md']
# ..                                                 ...
# 530  ['---bug-report.md', '---crash-report.md', '--...
# 533  ['bug_report.md', 'feature_request.md', 'gener...
# 534            ['bug-report.md', 'feature-request.md']
# 536  ['bug_report.md', 'feature-suggestion.md', 'ot...
# 537            ['bug_report.md', 'feature_request.md']
#
#                     nameWithOwner           owner  \
# 1         getify/You-Dont-Know-JS          getify
# 3                 flutter/flutter         flutter
# 4                microsoft/vscode       microsoft
# 6             ytdl-org/youtube-dl        ytdl-org
# 7    labuladong/fucking-algorithm      labuladong
# ..                            ...             ...
# 530    mozilla-mobile_firefox-ios  mozilla-mobile
# 533          daltoniam_Starscream       daltoniam
# 534                     Lona_Lona            Lona
# 536          lwouis_alt-tab-macos          lwouis
# 537         huri000_SwiftEntryKit         huri000
#
#                                     issue_files_to_str  \
# 1    content-question.md,foreign-translation-reques...
# 3    4_performance_others.md,5_performance_speed.md...
# 4                     bug_report.md,feature_request.md
# 6    1_broken_site.md,2_site_support_request.md,3_s...
# 7                               others.md,translate.md
# ..                                                 ...
# 530  ---bug-report.md,---crash-report.md,---feature...
# 533  bug_report.md,feature_request.md,general-quest...
# 534                   bug-report.md,feature-request.md
# 536       bug_report.md,feature-suggestion.md,other.md
# 537                   bug_report.md,feature_request.md
#
#     pull_request_files_to_str  len_of_issue_files  len_of_pull_request_files
# 1    PULL_REQUEST_TEMPLATE.md                   4                          1
# 3    PULL_REQUEST_TEMPLATE.md                   3                          1
# 4    pull_request_template.md                   2                          1
# 6    PULL_REQUEST_TEMPLATE.md                   6                          1
# 7    PULL_REQUEST_TEMPLATE.md                   2                          1
# ..                        ...                 ...                        ...
# 530     PULL_REQUEST_TEMPLATE                   6                          1
# 533  pull_request_template.md                   3                          1
# 534  PULL_REQUEST_TEMPLATE.md                   2                          1
# 536  pull_request_template.md                   3                          1
# 537  PULL_REQUEST_TEMPLATE.md                   2                          1
#
# [442 rows x 12 columns]
#     primaryLanguage                                        description  \
# 15       JavaScript  24 Lessons, 12 Weeks, Get Started as a Web Dev...
# 22       TypeScript                             VS Code in the browser
# 23       TypeScript    Predictable state container for JavaScript apps
# 51           Python  openpilot is an open source driver assistance ...
# 81          Clojure  The simplest, fastest way to get business inte...
# 83               C#  ASP.NET Core is a cross-platform .NET framewor...
# 87       JavaScript   🤪 A list of funny and tricky JavaScript examples
# 92       JavaScript   A markdown parser and compiler. Built for speed.
# 224             PHP                    The PHP Unit Testing framework.
# 232             PHP            Doctrine Object Relational Mapper (ORM)
# 284      JavaScript  24 Lessons, 12 Weeks, Get Started as a Web Dev...
# 291      TypeScript                             VS Code in the browser
# 292      TypeScript    Predictable state container for JavaScript apps
# 320          Python  openpilot is an open source driver assistance ...
# 350         Clojure  The simplest, fastest way to get business inte...
# 352              C#  ASP.NET Core is a cross-platform .NET framewor...
# 356      JavaScript   🤪 A list of funny and tricky JavaScript examples
# 361      JavaScript   A markdown parser and compiler. Built for speed.
# 493             PHP                    The PHP Unit Testing framework.
# 501             PHP            Doctrine Object Relational Mapper (ORM)
#
#      hasWikiEnabled  stargazerCount  \
# 15             True           69309
# 22            False           60223
# 23            False           59543
# 51             True           39263
# 81             True           32256
# 83             True           31634
# 87            False           30855
# 92            False           29642
# 224           False           19072
# 232           False            9576
# 284            True           69309
# 291           False           60223
# 292           False           59543
# 320            True           39263
# 350            True           32256
# 352            True           31634
# 356           False           30855
# 361           False           29642
# 493           False           19072
# 501           False            9576
#
#                                     pull_request_files  \
# 15   ['translation_checklist.md', 'translation_chec...
# 22   ['PULL_REQUEST_TEMPLATE.md', 'release_template...
# 23   ['PULL_REQUEST_TEMPLATE.md', 'bugfix.md', 'doc...
# 51   ['pull_request_template.md', 'bugfix.md', 'car...
# 81    ['PULL_REQUEST_TEMPLATE.md', 'cypress_repro.md']
# 83        ['pull_request_template.md', 'servicing.md']
# 87                ['new_example.md', 'translation.md']
# 92           ['PULL_REQUEST_TEMPLATE.md', 'badges.md']
# 224  ['FAILING_TEST.md', 'FIX.md', 'IMPROVEMENT.md'...
# 232  ['Failing_Test.md', 'Improvement.md', 'New_Fea...
# 284  ['translation_checklist.md', 'translation_chec...
# 291  ['PULL_REQUEST_TEMPLATE.md', 'release_template...
# 292  ['PULL_REQUEST_TEMPLATE.md', 'bugfix.md', 'doc...
# 320  ['pull_request_template.md', 'bugfix.md', 'car...
# 350   ['PULL_REQUEST_TEMPLATE.md', 'cypress_repro.md']
# 352       ['pull_request_template.md', 'servicing.md']
# 356               ['new_example.md', 'translation.md']
# 361          ['PULL_REQUEST_TEMPLATE.md', 'badges.md']
# 493  ['FAILING_TEST.md', 'FIX.md', 'IMPROVEMENT.md'...
# 501  ['Failing_Test.md', 'Improvement.md', 'New_Fea...
#
#                                            issue_files  \
# 15   ['bug_report.md', 'feature_request.md', 'trans...
# 22                    ['doc.md', 'feature-request.md']
# 23   ['Bug_report.md', 'Feature_request.md', 'docum...
# 51                                  ['enhancement.md']
# 81   ['feature-or-project-implementation.md', 'feat...
# 83   ['30_api_proposal.md', '40_design_proposal.md'...
# 87                                  ['new-example.md']
# 92   ['Bug_report.md', 'Feature_request.md', 'Propo...
# 224  ['1_BUG.md', '2_BUG_PHPUNIT_10.md', '3_BUG_PHP...
# 232  ['BC_Break.md', 'Bug.md', 'Feature_Request.md'...
# 284  ['bug_report.md', 'feature_request.md', 'trans...
# 291                   ['doc.md', 'feature-request.md']
# 292  ['Bug_report.md', 'Feature_request.md', 'docum...
# 320                                 ['enhancement.md']
# 350  ['feature-or-project-implementation.md', 'feat...
# 352  ['30_api_proposal.md', '40_design_proposal.md'...
# 356                                 ['new-example.md']
# 361  ['Bug_report.md', 'Feature_request.md', 'Propo...
# 493  ['1_BUG.md', '2_BUG_PHPUNIT_10.md', '3_BUG_PHP...
# 501  ['BC_Break.md', 'Bug.md', 'Feature_Request.md'...
#
#                        nameWithOwner              owner  \
# 15   microsoft/Web-Dev-For-Beginners          microsoft
# 22                 coder/code-server              coder
# 23                     reduxjs/redux            reduxjs
# 51                 commaai/openpilot            commaai
# 81                 metabase/metabase           metabase
# 83                 dotnet/aspnetcore             dotnet
# 87                 denysdovhan/wtfjs        denysdovhan
# 92                   markedjs/marked           markedjs
# 224        sebastianbergmann/phpunit  sebastianbergmann
# 232                     doctrine/orm           doctrine
# 284  microsoft_Web-Dev-For-Beginners          microsoft
# 291                coder_code-server              coder
# 292                    reduxjs_redux            reduxjs
# 320                commaai_openpilot            commaai
# 350                metabase_metabase           metabase
# 352                dotnet_aspnetcore             dotnet
# 356                denysdovhan_wtfjs        denysdovhan
# 361                  markedjs_marked           markedjs
# 493        sebastianbergmann_phpunit  sebastianbergmann
# 501                     doctrine_orm           doctrine
#
#                                     issue_files_to_str  \
# 15   bug_report.md,feature_request.md,translations_...
# 22                           doc.md,feature-request.md
# 23   Bug_report.md,Feature_request.md,documentation...
# 51                                      enhancement.md
# 81   feature-or-project-implementation.md,feature_r...
# 83   30_api_proposal.md,40_design_proposal.md,50_te...
# 87                                      new-example.md
# 92        Bug_report.md,Feature_request.md,Proposal.md
# 224  1_BUG.md,2_BUG_PHPUNIT_10.md,3_BUG_PHPUNIT_9.m...
# 232  BC_Break.md,Bug.md,Feature_Request.md,Support_...
# 284  bug_report.md,feature_request.md,translations_...
# 291                          doc.md,feature-request.md
# 292  Bug_report.md,Feature_request.md,documentation...
# 320                                     enhancement.md
# 350  feature-or-project-implementation.md,feature_r...
# 352  30_api_proposal.md,40_design_proposal.md,50_te...
# 356                                     new-example.md
# 361       Bug_report.md,Feature_request.md,Proposal.md
# 493  1_BUG.md,2_BUG_PHPUNIT_10.md,3_BUG_PHPUNIT_9.m...
# 501  BC_Break.md,Bug.md,Feature_Request.md,Support_...
#
#                              pull_request_files_to_str  len_of_issue_files  \
# 15   translation_checklist.md,translation_checklist...                   3
# 22        PULL_REQUEST_TEMPLATE.md,release_template.md                   2
# 23   PULL_REQUEST_TEMPLATE.md,bugfix.md,documentati...                   4
# 51   pull_request_template.md,bugfix.md,car_bugfix....                   1
# 81           PULL_REQUEST_TEMPLATE.md,cypress_repro.md                   2
# 83               pull_request_template.md,servicing.md                   4
# 87                       new_example.md,translation.md                   1
# 92                  PULL_REQUEST_TEMPLATE.md,badges.md                   3
# 224  FAILING_TEST.md,FIX.md,IMPROVEMENT.md,NEW_FEAT...                   7
# 232      Failing_Test.md,Improvement.md,New_Feature.md                   4
# 284  translation_checklist.md,translation_checklist...                   3
# 291       PULL_REQUEST_TEMPLATE.md,release_template.md                   2
# 292  PULL_REQUEST_TEMPLATE.md,bugfix.md,documentati...                   4
# 320  pull_request_template.md,bugfix.md,car_bugfix....                   1
# 350          PULL_REQUEST_TEMPLATE.md,cypress_repro.md                   2
# 352              pull_request_template.md,servicing.md                   4
# 356                      new_example.md,translation.md                   1
# 361                 PULL_REQUEST_TEMPLATE.md,badges.md                   3
# 493  FAILING_TEST.md,FIX.md,IMPROVEMENT.md,NEW_FEAT...                   7
# 501      Failing_Test.md,Improvement.md,New_Feature.md                   4
#
#      len_of_pull_request_files
# 15                           2
# 22                           2
# 23                           4
# 51                           7
# 81                           2
# 83                           2
# 87                           2
# 92                           2
# 224                          4
# 232                          3
# 284                          2
# 291                          2
# 292                          4
# 320                          7
# 350                          2
# 352                          2
# 356                          2
# 361                          2
# 493                          4
# 501                          3

# %%
len(df)
# Out:
# 538

# %%
issue_contents_df = pd.read_csv('individual_issue_contents.csv')

issue_contents_df = issue_contents_df.dropna(subset=['issue_file', 'body'], how='all')
issue_contents_df = issue_contents_df[(issue_contents_df['issue_file'] != '') & (issue_contents_df['body'] != '')]
issue_contents_df = issue_contents_df.reset_index(drop=True)
issue_contents_df = issue_contents_df.reset_index(drop=True)

issue_contents_df.head()
# Out:
#                       repo     owner                      issue_file  title  \
# 0           facebook/react  facebook                   bug_report.md  Bug:
# 1  getify/You-Dont-Know-JS    getify             content-question.md    NaN
# 2  getify/You-Dont-Know-JS    getify  foreign-translation-request.md    NaN
# 3  getify/You-Dont-Know-JS    getify     report-technical-mistake.md    NaN
# 4  getify/You-Dont-Know-JS    getify         textual-grammar-typo.md    NaN
#
#                                                 body  \
# 0  <!--\n  Please provide a clear and concise des...
# 1  **Yes, I promise I've read the [Contributions ...
# 2  Foreign translations are appreciated. However,...
# 3  **Yes, I promise I've read the [Contributions ...
# 4  **Yes, I promise I've read the [Contributions ...
#
#                           name
# 0                 🐛 Bug Report
# 1             Content Question
# 2  Foreign Translation Request
# 3     Report Technical Mistake
# 4         Textual/Grammar Typo

# %%
# print same repo and owner but different issue_file
different_issue_file = issue_contents_df[issue_contents_df.duplicated(subset=['repo', 'owner'], keep=False)]
print(different_issue_file)
# Out:
#                          repo      owner                      issue_file  \
# 0              facebook/react   facebook                   bug_report.md
# 1     getify/You-Dont-Know-JS     getify             content-question.md
# 2     getify/You-Dont-Know-JS     getify  foreign-translation-request.md
# 3     getify/You-Dont-Know-JS     getify     report-technical-mistake.md
# 4     getify/You-Dont-Know-JS     getify         textual-grammar-typo.md
# ...                       ...        ...                             ...
# 6569              forem_forem      forem                   bug_report.md
# 6570         go-kratos_kratos  go-kratos                   bug-report.md
# 6571         go-kratos_kratos  go-kratos              feature-request.md
# 6572         go-kratos_kratos  go-kratos                     proposal.md
# 6573         go-kratos_kratos  go-kratos                     question.md
#
#            title                                               body  \
# 0          Bug:   <!--\n  Please provide a clear and concise des...
# 1            NaN  **Yes, I promise I've read the [Contributions ...
# 2            NaN  Foreign translations are appreciated. However,...
# 3            NaN  **Yes, I promise I've read the [Contributions ...
# 4            NaN  **Yes, I promise I've read the [Contributions ...
# ...          ...                                                ...
# 6569         NaN  <!-- Before creating a bug report, try disabli...
# 6570         NaN  <!--\nPlease answer these questions before sub...
# 6571   [Feature]  Please see the FAQ in our main README.md befor...
# 6572  [Proposal]  Please see the FAQ in our main README.md befor...
# 6573  [Question]  Please see the FAQ in our main README.md befor...
#
#                              name
# 0                    🐛 Bug Report
# 1                Content Question
# 2     Foreign Translation Request
# 3        Report Technical Mistake
# 4            Textual/Grammar Typo
# ...                           ...
# 6569                   Bug report
# 6570                 🐛 Bug Report
# 6571            💡 Feature Request
# 6572           🧱 Proposal Request
# 6573                   🚀 Question
#
# [6535 rows x 6 columns]

# %%
pr_contents_df = pd.read_csv('individual_pr_contents.csv')

pr_contents_df = pr_contents_df.dropna(subset=['pr_file', 'body'], how='all')
pr_contents_df = pr_contents_df[(pr_contents_df['pr_file'] != '') & (pr_contents_df['body'] != '')]
pr_contents_df = pr_contents_df.reset_index(drop=True)
pr_contents_df = pr_contents_df.reset_index(drop=True)

pr_contents_df.head()
# Out:
#                       repo      owner                   pr_file  \
# 0           facebook/react   facebook  PULL_REQUEST_TEMPLATE.md
# 1  getify/You-Dont-Know-JS     getify  PULL_REQUEST_TEMPLATE.md
# 2     vinta/awesome-python      vinta  PULL_REQUEST_TEMPLATE.md
# 3          flutter/flutter    flutter  PULL_REQUEST_TEMPLATE.md
# 4         microsoft/vscode  microsoft  pull_request_template.md
#
#                                                 body
# 0  <!--\n  Thanks for submitting a pull request!\...
# 1  **Yes, I promise I've read the [Contributions ...
# 2  ## What is this Python project?\n\nDescribe fe...
# 3  *Replace this paragraph with a description of ...
# 4  <!-- Thank you for submitting a Pull Request. ...

# %%
different_pr_file = pr_contents_df[pr_contents_df.duplicated(subset=['repo', 'owner'], keep=False)]


# print the owner and repo and pr_file
print(different_pr_file[['owner', 'repo', 'pr_file']])
# Out:
#                       owner                                         repo  \
# 0                  facebook                               facebook/react
# 2                     vinta                         vinta/awesome-python
# 4                 microsoft                             microsoft/vscode
# 6                  ytdl-org                          ytdl-org/youtube-dl
# 8                    golang                                    golang/go
# ...                     ...                                          ...
# 2511               markedjs                              markedjs_marked
# 2526         ianstormtaylor                         ianstormtaylor_slate
# 2528                 mobxjs                                  mobxjs_mobx
# 2554  react-native-elements  react-native-elements_react-native-elements
# 2561                 doczjs                                  doczjs_docz
#
#                        pr_file
# 0     PULL_REQUEST_TEMPLATE.md
# 2     PULL_REQUEST_TEMPLATE.md
# 4     pull_request_template.md
# 6     PULL_REQUEST_TEMPLATE.md
# 8        PULL_REQUEST_TEMPLATE
# ...                        ...
# 2511                 badges.md
# 2526  PULL_REQUEST_TEMPLATE.md
# 2528  PULL_REQUEST_TEMPLATE.md
# 2554  PULL_REQUEST_TEMPLATE.md
# 2561  PULL_REQUEST_TEMPLATE.md
#
# [2368 rows x 3 columns]
